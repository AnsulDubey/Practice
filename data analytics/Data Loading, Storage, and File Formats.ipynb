# 1            24.735104         291.911407
# 2            24.329473         288.329681
# 3            23.868181         289.606384
# 4            23.033073         273.227905
# 5            23.319397         268.255249
# 6            23.462553         269.457428
# 7            23.597769         269.298462
# 8            23.192135         265.418701
# 9            22.412704         263.257751
# 10           22.595629         264.787811
# 11           22.635405         263.843964
# 12           22.770605         268.662598
# 13           22.142290         261.687958
# 14           22.285454         263.928406
# 15           22.046848         265.011353
# 16           22.277498         266.486755
# 17           22.261591         265.498199
# 18           22.364988         266.466888
# 19           22.213871         264.837494
# 20           22.653355         268.901062
# 21           22.845131         267.366028
# 22           23.148769         269.854858
# 23           22.988953         268.632812
# 24           22.956991         269.646210
# 25           22.637369         265.806183
# 26           22.877089         264.017822
# 27           22.853115         261.514099
# 28           22.909052         261.697906
# 29           23.188726         264.623871
# ..                 ...                ...
# 60           24.627035         292.596924
# 61           24.666983         295.726593
# 62           24.507175         273.297455
# 63           24.802820         273.272614
# 64           25.058521         275.726654
# 65           25.034548         275.359070
# 66           25.082495         271.762451
# 67           24.738905         270.734131
# 68           24.858755         264.102264
# 69           24.651001         262.820618
# 70           24.698944         262.885193
# 71           24.770861         264.281097
# 72           24.403294         261.151459
# 73           24.658993         263.585632
# 74           24.075682         251.548920
# 75           23.851942         253.232971
# 76           23.156761         247.723801
# 77           22.541483         244.976669
# 78           23.124798         259.139557
# 79           23.076849         252.880264
# 80           23.524330         251.062088
# 81           23.364517         253.789352
# 82           23.116808         252.125168
# 83           23.124798         252.343750
# 84           22.956236         247.574768
# 85           22.667269         245.617493
# 86           21.760265         235.970245
# 87           21.543539         234.499802
# 88           21.086029         237.038300
# 89           20.925493         236.993591
#
# [90 rows x 6 columns]

# %%
pd.isnull(df)
# Out:
#      Date  Apple    IBM  Microsoft  Google
# 0   False  False  False      False   False
# 1   False  False  False      False   False
# 2   False  False  False      False   False
# 3   False  False  False      False   False
# 4   False  False  False      False   False
# 5   False  False  False      False   False
# 6   False  False  False      False   False
# 7   False  False  False      False   False
# 8   False  False  False      False   False
# 9   False  False  False      False   False
# 10  False  False  False      False   False
# 11  False  False  False      False   False
# 12  False  False  False      False   False
# 13  False  False  False      False   False
# 14  False  False  False      False   False
# 15  False  False  False      False   False
# 16  False  False  False      False   False
# 17  False  False  False      False   False
# 18  False  False  False      False   False
# 19  False  False  False      False   False
# 20  False  False  False      False   False

# %%
pd.options.display.max_rows=10

# %%
# Out:
#           Date               Apple                 IBM           Microsoft  \
# 0   2009-12-31  20.073631286621094   99.30300903320312   24.24198341369629
# 1   2010-01-04  20.386072158813477  100.47886657714844  24.615800857543945
# 2   2010-01-05  20.421321868896484   99.26509094238281  24.623754501342773
# 3   2010-01-06   20.09649085998535   98.62025451660156  24.472631454467773
# 4   2010-01-07  20.059337615966797   98.27886962890625  24.218124389648438
# ..         ...                 ...                 ...                 ...
# 16  2010-01-26  19.617345809936523   95.39615631103516  23.462553024291992
# 17  2010-01-27  19.802146911621094   95.83614349365234  23.597768783569336
# 18  2010-01-28  18.983882904052734         93.87890625  23.192134857177734
# 19  2010-01-29  18.295169830322266   92.84717559814453  22.412704467773438
# 20  2010-05-25   23.35906410217285   95.37189483642578  20.925493240356445
#
#                 Google
# 0    307.9868469238281
# 1    311.3499755859375
# 2    309.9788818359375
# 3    302.1647033691406
# 4    295.1304626464844
# ..                 ...
# 16   269.4574279785156
# 17   269.2984619140625
# 18    265.418701171875
# 19  263.25775146484375
# 20  236.99359130859375
#
# [21 rows x 5 columns]

# %%
pd.read_csv('price_data.csv',nrows=5)
# Out:
#    Unnamed: 0        Date      Apple         IBM  Microsoft      Google
# 0           1  2009-12-31  20.073631   99.303009  24.241983  307.986847
# 1           2  2010-01-04  20.386072  100.478867  24.615801  311.349976
# 2           3  2010-01-05  20.421322   99.265091  24.623755  309.978882
# 3           4  2010-01-06  20.096491   98.620255  24.472631  302.164703
# 4           5  2010-01-07  20.059338   98.278870  24.218124  295.130463

# %%
chunk=pd.read_csv('price_data.csv',chunksize=100)

# %%
chunk

# %%
df
# Out:
#           Date               Apple                 IBM           Microsoft  \
# 0   2009-12-31  20.073631286621094   99.30300903320312   24.24198341369629
# 1   2010-01-04  20.386072158813477  100.47886657714844  24.615800857543945
# 2   2010-01-05  20.421321868896484   99.26509094238281  24.623754501342773
# 3   2010-01-06   20.09649085998535   98.62025451660156  24.472631454467773
# 4   2010-01-07  20.059337615966797   98.27886962890625  24.218124389648438
# ..         ...                 ...                 ...                 ...
# 16  2010-01-26  19.617345809936523   95.39615631103516  23.462553024291992
# 17  2010-01-27  19.802146911621094   95.83614349365234  23.597768783569336
# 18  2010-01-28  18.983882904052734         93.87890625  23.192134857177734
# 19  2010-01-29  18.295169830322266   92.84717559814453  22.412704467773438
# 20  2010-05-25   23.35906410217285   95.37189483642578  20.925493240356445
#
#                 Google
# 0    307.9868469238281
# 1    311.3499755859375
# 2    309.9788818359375
# 3    302.1647033691406
# 4    295.1304626464844
# ..                 ...
# 16   269.4574279785156
# 17   269.2984619140625
# 18    265.418701171875
# 19  263.25775146484375
# 20  236.99359130859375
#
# [21 rows x 5 columns]

# %%
df.describe(exclude='Date')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-ad3615682650> in <module>
# ----> 1 df.describe(exclude='Date')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in describe(self, percentiles, include, exclude)
#    9800             data = self
#    9801         else:
# -> 9802             data = self.select_dtypes(include=include, exclude=exclude)
#    9803
#    9804         ldesc = [describe_1d(s) for _, s in data.iteritems()]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in select_dtypes(self, include, exclude)
#    3304         # convert the myriad valid dtypes object to a single representation
#    3305         include, exclude = map(
# -> 3306             lambda x: frozenset(map(infer_dtype_from_object, x)), selection)
#    3307         for dtypes in (include, exclude):
#    3308             invalidate_string_dtypes(dtypes)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in <lambda>(x)
#    3304         # convert the myriad valid dtypes object to a single representation
#    3305         include, exclude = map(
# -> 3306             lambda x: frozenset(map(infer_dtype_from_object, x)), selection)
#    3307         for dtypes in (include, exclude):
#    3308             invalidate_string_dtypes(dtypes)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/common.py in infer_dtype_from_object(dtype)
#    1951             pass
#    1952
# -> 1953     return infer_dtype_from_object(np.dtype(dtype))
#    1954
#    1955
#
# TypeError: data type "Date" not understood

# %%
df.drop(index=list(range(len(df))[10:]),inplace=True)

# %%
df
# Out:
#          Date               Apple                 IBM           Microsoft  \
# 0  2009-12-31  20.073631286621094   99.30300903320312   24.24198341369629
# 1  2010-01-04  20.386072158813477  100.47886657714844  24.615800857543945
# 2  2010-01-05  20.421321868896484   99.26509094238281  24.623754501342773
# 3  2010-01-06   20.09649085998535   98.62025451660156  24.472631454467773
# 4  2010-01-07  20.059337615966797   98.27886962890625  24.218124389648438
# 5  2010-01-08   20.19270133972168   99.26509094238281   24.38514518737793
# 6  2010-01-11  20.014568328857422   98.22577667236328  24.074966430664062
# 7  2010-01-12  19.786903381347656   99.00715637207031  23.915895462036133
# 8  2010-01-13   20.06600570678711   98.79474639892578  24.138591766357422
# 9  2010-01-14  19.949796676635742  100.37267303466797  24.623754501342773
#
#                Google
# 0   307.9868469238281
# 1   311.3499755859375
# 2   309.9788818359375
# 3   302.1647033691406
# 4   295.1304626464844
# 5  299.06488037109375
# 6   298.6128234863281
# 7   293.3321533203125
# 8   291.6481018066406
# 9   293.0191955566406

# %%
df.describe
# Out:
# <bound method NDFrame.describe of          Date               Apple                 IBM           Microsoft  \
# 0  2009-12-31  20.073631286621094   99.30300903320312   24.24198341369629
# 1  2010-01-04  20.386072158813477  100.47886657714844  24.615800857543945
# 2  2010-01-05  20.421321868896484   99.26509094238281  24.623754501342773
# 3  2010-01-06   20.09649085998535   98.62025451660156  24.472631454467773
# 4  2010-01-07  20.059337615966797   98.27886962890625  24.218124389648438
# 5  2010-01-08   20.19270133972168   99.26509094238281   24.38514518737793
# 6  2010-01-11  20.014568328857422   98.22577667236328  24.074966430664062
# 7  2010-01-12  19.786903381347656   99.00715637207031  23.915895462036133
# 8  2010-01-13   20.06600570678711   98.79474639892578  24.138591766357422
# 9  2010-01-14  19.949796676635742  100.37267303466797  24.623754501342773
#
#                Google
# 0   307.9868469238281
# 1   311.3499755859375
# 2   309.9788818359375
# 3   302.1647033691406
# 4   295.1304626464844
# 5  299.06488037109375
# 6   298.6128234863281
# 7   293.3321533203125
# 8   291.6481018066406
# 9   293.0191955566406  >

# %%
import numpy as np
df1=pd.DataFrame({'price':[1,2,3,4,5],'value':[12,20,30,40,50]},index=list('abcde'))

# %%
df1
# Out:
#    price  value
# a      1     12
# b      2     20
# c      3     30
# d      4     40
# e      5     50

# %%
df1.describe()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-784441b173b6> in <module>
# ----> 1 df1.describe()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in describe(self, percentiles, include, exclude)
#    9811                     names.append(name)
#    9812
# -> 9813         d = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
#    9814         d.columns = data.columns.copy()
#    9815         return d
#
# TypeError: 'list' object is not callable

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('price_data.csv',nrows=10)

# %%
df
# Out:
#    Unnamed: 0        Date      Apple         IBM  Microsoft      Google
# 0           1  2009-12-31  20.073631   99.303009  24.241983  307.986847
# 1           2  2010-01-04  20.386072  100.478867  24.615801  311.349976
# 2           3  2010-01-05  20.421322   99.265091  24.623755  309.978882
# 3           4  2010-01-06  20.096491   98.620255  24.472631  302.164703
# 4           5  2010-01-07  20.059338   98.278870  24.218124  295.130463
# 5           6  2010-01-08  20.192701   99.265091  24.385145  299.064880
# 6           7  2010-01-11  20.014568   98.225777  24.074966  298.612823
# 7           8  2010-01-12  19.786903   99.007156  23.915895  293.332153
# 9  2010-01-14  19.949797  100.372673  24.623755  293.019196

# %% [markdown]
# pickle is only recommended as a short-term storage format. The
# problem is that it is hard to guarantee that the format will be stable
# over time; an object pickled today may not unpickle with a later
# version of a library. We have tried to maintain backward compati‐
# bility when possible, but at some point in the future it may be nec‐
# essary to “break” the pickle format.

# %% [markdown]
# #### HDF5 format

# %% [markdown]
# Each HDF5 file can store multiple datasets and support‐
# ing metadata. Compared with simpler formats, HDF5 supports on-the-fly compres‐
# sion with a variety of compression modes, enabling data with repeated patterns to be
# stored more efficiently. HDF5 can be a good choice for working with very large data‐
# sets that don’t fit into memory, as you can efficiently read and write small sections of
# much larger arrays.

# %%
store=pd.HDFStore('mydata.h5')

# %%
store['obj1']=df

# %%
store['objcolumn']=df['IBM']

# %%
store
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: mydata.h5

# %%
store['obj1']
# Out:
#          Date      Apple         IBM  Microsoft      Google
# 0  2009-12-31  20.073631   99.303009  24.241983  307.986847
# 1  2010-01-04  20.386072  100.478867  24.615801  311.349976
# 2  2010-01-05  20.421322   99.265091  24.623755  309.978882
# 3  2010-01-06  20.096491   98.620255  24.472631  302.164703
# 4  2010-01-07  20.059338   98.278870  24.218124  295.130463
# 5  2010-01-08  20.192701   99.265091  24.385145  299.064880
# 6  2010-01-11  20.014568   98.225777  24.074966  298.612823
# 7  2010-01-12  19.786903   99.007156  23.915895  293.332153
# 8  2010-01-13  20.066006   98.794746  24.138592  291.648102
# 9  2010-01-14  19.949797  100.372673  24.623755  293.019196

# %%
store['objcolumn']
# Out:
# 0     99.303009
# 1    100.478867
# 2     99.265091
# 3     98.620255
# 4     98.278870
# 5     99.265091
# 6     98.225777
# 7     99.007156
# 8     98.794746
# 9    100.372673
# Name: IBM, dtype: float64

# %% [raw]
# HDFStore supports two storage schemas, 'fixed' and 'table' . The latter is generally
# slower, but it supports query operations using a special syntax:

# %%
store.put('obj2',df,format='table')

# %%
store.select('obj2',where=['index>=5 and index<=8'])
# Out:
#          Date      Apple        IBM  Microsoft      Google
# 5  2010-01-08  20.192701  99.265091  24.385145  299.064880
# 6  2010-01-11  20.014568  98.225777  24.074966  298.612823
# 7  2010-01-12  19.786903  99.007156  23.915895  293.332153
# 8  2010-01-13  20.066006  98.794746  24.138592  291.648102

# %%
store['obj2']
# Out:
#          Date      Apple         IBM  Microsoft      Google
# 0  2009-12-31  20.073631   99.303009  24.241983  307.986847
# 1  2010-01-04  20.386072  100.478867  24.615801  311.349976
# 2  2010-01-05  20.421322   99.265091  24.623755  309.978882
# 3  2010-01-06  20.096491   98.620255  24.472631  302.164703
# 4  2010-01-07  20.059338   98.278870  24.218124  295.130463
# 5  2010-01-08  20.192701   99.265091  24.385145  299.064880
# 6  2010-01-11  20.014568   98.225777  24.074966  298.612823
# 7  2010-01-12  19.786903   99.007156  23.915895  293.332153
# 8  2010-01-13  20.066006   98.794746  24.138592  291.648102
# 9  2010-01-14  19.949797  100.372673  24.623755  293.019196

# %%
store['obj1']+store['obj2']
# Out:
#                    Date      Apple         IBM  Microsoft      Google
# 0  2009-12-312009-12-31  40.147263  198.606018  48.483967  615.973694
# 1  2010-01-042010-01-04  40.772144  200.957733  49.231602  622.699951
# 2  2010-01-052010-01-05  40.842644  198.530182  49.247509  619.957764
# 3  2010-01-062010-01-06  40.192982  197.240509  48.945263  604.329407
# 4  2010-01-072010-01-07  40.118675  196.557739  48.436249  590.260925
# 5  2010-01-082010-01-08  40.385403  198.530182  48.770290  598.129761
# 6  2010-01-112010-01-11  40.029137  196.451553  48.149933  597.225647
# 7  2010-01-122010-01-12  39.573807  198.014313  47.831791  586.664307
# 8  2010-01-132010-01-13  40.132011  197.589493  48.277184  583.296204
# 9  2010-01-142010-01-14  39.899593  200.745346  49.247509  586.038391

# %%
store.close()

# %% [markdown]
# The pandas.read_hdf function gives you a shortcut to these tools:

# %%
df.to_hdf('mydata2.h5','obj3',format='table')

# %%
pd.read_hdf('mydata2.h5','obj3',where=['index>2 and index<7'])
# Out:
#          Date      Apple        IBM  Microsoft      Google
# 3  2010-01-06  20.096491  98.620255  24.472631  302.164703
# 4  2010-01-07  20.059338  98.278870  24.218124  295.130463
# 5  2010-01-08  20.192701  99.265091  24.385145  299.064880
# 6  2010-01-11  20.014568  98.225777  24.074966  298.612823

# %% [markdown]
# HDF5 is not a database. It is best suited for write-once, read-many
# datasets. While data can be added to a file at any time, if multiple
# writers do so simultaneously, the file can become corrupted.

# %% [markdown]
# ### Interacting with Web APIs

# %% [markdown]
# Many websites have public APIs providing data feeds via JSON or some other format.
# There are a number of ways to access these APIs from Python; one easy-to-use
# method that I recommend is the requests package.

# %%
import requests

# %%
url='https://api.github.com/repos/pandas-dev/pandas/issues'
resp=requests.get(url)

# %%
resp
# Out:
# <Response [200]>

# %%
data=resp.json()

# %%
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26321',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26321/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26321/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26321/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/26321',
#   'id': 442032769,
#   'node_id': 'MDU6SXNzdWU0NDIwMzI3Njk=',
#   'number': 26321,
#   'title': 'Bug: Groupby with as_index=True causes incorrect summarization',
#   'user': {'login': 'cdknox',
#    'id': 26149009,
#    'node_id': 'MDQ6VXNlcjI2MTQ5MDA5',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/26149009?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cdknox',
#    'html_url': 'https://github.com/cdknox',
#    'followers_url': 'https://api.github.com/users/cdknox/followers',
#    'following_url': 'https://api.github.com/users/cdknox/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/cdknox/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/cdknox/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/cdknox/subscriptions',
#    'organizations_url': 'https://api.github.com/users/cdknox/orgs',
#    'repos_url': 'https://api.github.com/users/cdknox/repos',
#    'events_url': 'https://api.github.com/users/cdknox/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/cdknox/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2019-05-09T03:28:12Z',
#   'updated_at': '2019-05-09T04:06:29Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'body': "#### Code Sample, a copy-pastable example:\r\n\r\n```python\r\nimport pandas as pd\r\nimport numpy as np\r\n\r\npd.show_versions()\r\n\r\ndates = ['2019-05-09', '2019-05-09', '2019-05-09']\r\ndate_series = pd.Series(dates)\r\n# it appears to happen on object dtype aggregations\r\n# where there is another object dtype in the frame with missing values\r\n# hence column 'a' being populated with strings\r\n# and missing and the dt.date accessor in 'c'\r\ndate_series_parsed = pd.to_datetime(date_series, format='%Y-%m-%d').dt.date\r\n\r\ndf = pd.DataFrame({\r\n    'a': [np.nan, '1', np.nan],\r\n    'b': [0, 1, 1],\r\n    'c': date_series_parsed,\r\n})  \r\n\r\n# as expected the series values returned are each populated with non missing data\r\n# I'm ignoring that this is returning a Series\r\n# and the other method returns a DataFrame\r\n# the logic is my real concern\r\nprint(df.groupby('b')['c'].min())\r\n# output (as is and as expected):\r\n# b\r\n# 0    2019-05-09\r\n# 1    2019-05-09\r\n# Name: c, dtype: object\r\n \r\n\r\n# looks like it's dependent on column 'a' being fully populated for some reason\r\n# as the group df['b'] == 1 min value is not returned appropriately here\r\n# but the group df['b'] == 0 min value does appear to be working\r\nprint(df.groupby('b', as_index=False)['c'].min())\r\n# output (as is):\r\n#    b           c\r\n# 0  0  2019-05-09\r\n# 1  1         NaN\r\n# \r\n# output (as expected):\r\n#    b           c \r\n# 0  0  2019-05-09\r\n# 1  1  2019-05-09\r\n```\r\n#### Problem description\r\n\r\nAs there is no missing value in column 'c', I would expect that every subgroup of the series would have the minimum as being well defined and non-missing.  This is consistent with the behavior shown when as_index in the groupby method is left as it's default parameter of False.  However it can clearly be seen that the minimum of column 'c' depends on column 'a' in some capacity.  It appears as though at some point in time the indexing is looking to column 'a' instead of column 'c' though I'm not sure why or when.\r\n\r\nI have tested this both on the version of pandas available on PyPI (0.24.2 as of the time of writing) and through the pandas-dev master branch.  The issue persists regardless of versions.  Furthermore the issue has been experienced on a variety of machines.\r\n\r\n\r\n#### Expected Output\r\n\r\nI would expect the results to be consistent with the calculation performed when as_index is left as it's default value of False, as it seems that the minimum of the values which comprise the group where column b is equal to 1 is a well defined result (explicitly 2019-05-09).\r\n\r\nThank you for the consideration!\r\n\r\n#### Output of ``pd.show_versions()``\r\nNote: I ran this on the master branch, and 0.24.2, the below is the output from the master branch.  If this is insufficient please let me know and I will supplement with the PyPI version of 0.24.2 when able.\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit: None\r\npython: 3.7.2.final.0\r\npython-bits: 64\r\nOS: Linux\r\nOS-release: 5.0.4-arch1-1-ARCH\r\nmachine: x86_64\r\nprocessor: \r\nbyteorder: little\r\nLC_ALL: None\r\nLANG: C\r\nLOCALE: None.None\r\n\r\npandas: 0+unknown\r\npytest: None\r\npip: 18.1\r\nsetuptools: 40.8.0\r\nCython: 0.29.7\r\nnumpy: 1.16.1\r\nscipy: 1.2.1\r\npyarrow: None\r\nxarray: None\r\nIPython: 7.2.0\r\nsphinx: None\r\npatsy: None\r\ndateutil: 2.8.0\r\npytz: 2018.9\r\nblosc: None\r\nbottleneck: None\r\ntables: None\r\nnumexpr: None\r\nfeather: None\r\nmatplotlib: 3.0.3\r\nopenpyxl: 2.6.1\r\nxlrd: 1.2.0\r\nxlwt: None\r\nxlsxwriter: None\r\nlxml.etree: 4.3.2\r\nbs4: None\r\nhtml5lib: 1.0.1\r\nsqlalchemy: None\r\npymysql: None\r\npsycopg2: None\r\njinja2: 2.10\r\ns3fs: None\r\nfastparquet: None\r\npandas_gbq: None\r\npandas_datareader: None\r\ngcsfs: None\r\n\r\n</details>\r\n"},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26320',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26320/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26320/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26320/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/26320',
#   'id': 441899956,
#   'node_id': 'MDU6SXNzdWU0NDE4OTk5NTY=',
#   'number': 26320,
#   'title': '__or__ (and others?) should return NotImplemented for custom classes',
#   'user': {'login': 'adamklein',
#    'id': 869232,
#    'node_id': 'MDQ6VXNlcjg2OTIzMg==',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/869232?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/adamklein',
#    'html_url': 'https://github.com/adamklein',
#    'followers_url': 'https://api.github.com/users/adamklein/followers',
#    'following_url': 'https://api.github.com/users/adamklein/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/adamklein/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/adamklein/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/adamklein/subscriptions',
#    'organizations_url': 'https://api.github.com/users/adamklein/orgs',
#    'repos_url': 'https://api.github.com/users/adamklein/repos',
#    'events_url': 'https://api.github.com/users/adamklein/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/adamklein/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 35818298,
#     'node_id': 'MDU6TGFiZWwzNTgxODI5OA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/API%20Design',
#     'name': 'API Design',
#     'color': 'AD7FA8',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2019-05-08T19:44:41Z',
#   'updated_at': '2019-05-08T22:48:04Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'body': "#### Code Sample, a copy-pastable example if possible\r\n\r\n```python\r\nIn [1]: class Test:\r\n   ...:     def __ror__(self, other):\r\n   ...:         print('here')\r\n   ...:         return self\r\n   ...: \r\n\r\nIn [2]: {} | Test()\r\nhere\r\nOut[2]: <__main__.Test at 0x7f37a1601ba8>\r\n\r\nIn [3]: import pandas\r\n\r\nIn [4]: pandas.DataFrame() | Test()\r\nOut[4]: \r\nEmpty DataFrame\r\nColumns: []\r\nIndex: []\r\n```\r\n#### Problem description\r\n\r\nI would expect DataFrame to return `NotImplemented` in this case, so we can properly delegate to `__ror__`.\r\n\r\n#### Expected Output\r\n\r\n```\r\nOut[3]: <__main__.Test at 0x7f37a1601ba8>\r\n```\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nIn [4]: pd.show_versions()\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit: None\r\npython: 3.6.6.final.0\r\npython-bits: 64\r\nOS: Linux\r\nOS-release: 4.14.67-ts1\r\nmachine: x86_64\r\nprocessor: \r\nbyteorder: little\r\nLC_ALL: None\r\nLANG: en_US.utf8\r\nLOCALE: en_US.UTF-8\r\n\r\npandas: 0.24.2\r\npytest: 4.4.1\r\npip: 19.0.3\r\nsetuptools: 40.8.0\r\nCython: 0.29.6\r\nnumpy: 1.15.4\r\nscipy: 1.2.1\r\npyarrow: 0.11.1\r\nxarray: None\r\nIPython: 7.4.0\r\nsphinx: 2.0.1\r\npatsy: 0.5.1\r\ndateutil: 2.8.0\r\npytz: 2018.9\r\nblosc: None\r\nbottleneck: None\r\ntables: 3.5.1\r\nnumexpr: 2.6.9\r\nfeather: None\r\nmatplotlib: 3.0.3\r\nopenpyxl: None\r\nxlrd: None\r\nxlwt: None\r\nxlsxwriter: 1.1.5\r\nlxml.etree: None\r\nbs4: 4.7.1\r\nhtml5lib: None\r\nsqlalchemy: None\r\npymysql: None\r\npsycopg2: None\r\njinja2: 2.10\r\ns3fs: 0.2.0\r\nfastparquet: None\r\npandas_gbq: None\r\npandas_datareader: None\r\ngcsfs: None\r\n\r\n</details>\r\n"},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26319',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26319/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26319/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26319/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/26319',
#   'id': 441798290,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Mjc3MDQ3ODQz',
#   'number': 26319,
#   'title': 'CLN: remove compat.lrange, part 3',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
#    'followers_url': 'https://api.github.com/users/topper-123/followers',
#    'following_url': 'https://api.github.com/users/topper-123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/topper-123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/topper-123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/topper-123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/topper-123/orgs',
#    'repos_url': 'https://api.github.com/users/topper-123/repos',
#    'events_url': 'https://api.github.com/users/topper-123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/topper-123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 49747336,
#     'node_id': 'MDU6TGFiZWw0OTc0NzMzNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/2/3%20Compat',
#     'name': '2/3 Compat',
#     'color': 'c7eef8',
#     'default': False},
#    {'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2019-05-08T15:34:45Z',
#   'updated_at': '2019-05-08T20:33:25Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/26319',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/26319',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/26319.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/26319.patch'},
#   'body': '- [x] xref #25725, #26281 & #26289\r\n\r\nThird part of the removal of ``compat.lrange`` from the code base.'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26316',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26316/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26316/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26316/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/26316',
#   'id': 441697121,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Mjc2OTY3Nzgy',
#   'number': 26316,
#   'title': '[ENH] Use default EA repr for IntervalArray',
#   'user': {'login': 'makbigc',
#    'id': 14367887,
#    'node_id': 'MDQ6VXNlcjE0MzY3ODg3',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/14367887?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/makbigc',
#    'html_url': 'https://github.com/makbigc',
#    'followers_url': 'https://api.github.com/users/makbigc/followers',
#    'following_url': 'https://api.github.com/users/makbigc/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/makbigc/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/makbigc/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/makbigc/subscriptions',
#    'organizations_url': 'https://api.github.com/users/makbigc/orgs',
#    'repos_url': 'https://api.github.com/users/makbigc/repos',
#    'events_url': 'https://api.github.com/users/makbigc/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/makbigc/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 849023693,
#     'node_id': 'MDU6TGFiZWw4NDkwMjM2OTM=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/ExtensionArray',
#     'name': 'ExtensionArray',
#     'color': '6138b5',
#     'default': False},
#    {'id': 150096370,
#     'node_id': 'MDU6TGFiZWwxNTAwOTYzNzA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Interval',
#     'name': 'Interval',
#     'color': '009800',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2019-05-08T11:55:19Z',
#   'updated_at': '2019-05-08T18:28:15Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/26316',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/26316',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/26316.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/26316.patch'},
#   'body': '- [x] closes #25022\r\n- [x] 1 test deleted\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [ ] whatsnew entry\r\n'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26315',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26315/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26315/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26315/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/26315',
#   'id': 441680417,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Mjc2OTU0ODc5',
#   'number': 26315,
#   'title': 'Remove other pandas.core.index files from MyPy Blacklist ',
#   'user': {'login': 'makbigc',
#    'id': 14367887,
#    'node_id': 'MDQ6VXNlcjE0MzY3ODg3',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/14367887?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/makbigc',
#    'html_url': 'https://github.com/makbigc',
#    'followers_url': 'https://api.github.com/users/makbigc/followers',
#    'following_url': 'https://api.github.com/users/makbigc/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/makbigc/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/makbigc/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/makbigc/subscriptions',
#    'organizations_url': 'https://api.github.com/users/makbigc/orgs',
#    'repos_url': 'https://api.github.com/users/makbigc/repos',
#    'events_url': 'https://api.github.com/users/makbigc/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/makbigc/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 1280988427,
#     'node_id': 'MDU6TGFiZWwxMjgwOTg4NDI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Typing',
#     'name': 'Typing',
#     'color': 'ea91a4',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2019-05-08T11:11:20Z',
#   'updated_at': '2019-05-08T15:03:47Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/26315',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/26315',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/26315.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/26315.patch'},
#   'body': '- [x] closes one issue of #25882\r\n- [ ] tests added / passed\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [ ] whatsnew entry\r\n'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26314',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26314/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26314/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26314/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/26314',
#   'id': 441643259,
#   'node_id': 'MDU6SXNzdWU0NDE2NDMyNTk=',
#   'number': 26314,
#   'title': 'Pivot / unstack on large data frame does not work int32 overflow',
#   'user': {'login': 'MarkiesFredje',
#    'id': 28642372,
#    'node_id': 'MDQ6VXNlcjI4NjQyMzcy',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/28642372?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarkiesFredje',
#    'html_url': 'https://github.com/MarkiesFredje',
#    'followers_url': 'https://api.github.com/users/MarkiesFredje/followers',
#    'following_url': 'https://api.github.com/users/MarkiesFredje/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MarkiesFredje/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MarkiesFredje/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MarkiesFredje/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MarkiesFredje/orgs',
#    'repos_url': 'https://api.github.com/users/MarkiesFredje/repos',
#    'events_url': 'https://api.github.com/users/MarkiesFredje/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MarkiesFredje/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 47223669,
#     'node_id': 'MDU6TGFiZWw0NzIyMzY2OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Numeric',
#     'name': 'Numeric',
#     'color': '006b75',
#     'default': False},
#    {'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 7,
#   'created_at': '2019-05-08T09:39:49Z',
#   'updated_at': '2019-05-08T22:49:07Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'body': '#### Code Sample, a copy-pastable example if possible\r\n\r\n```python\r\npredictor_purchases_p = predictor_purchases.groupby(["ag", "artikelnr"])["som"].max().unstack().fillna(0)\r\n\r\nor\r\n\r\npredictor_purchases_p = predictor_purchases.pivot(index="ag", columns="artikelnr", value="som")\r\n```\r\n#### Problem description\r\nI\'m working on rather large data (>100GB in memory) on a beefy server (3TB ram)\r\nWhen refactoring my code from pandas 0.21 to latest version, the pivot / unstack now returns an exception.\r\n\r\nUnstacked DataFrame is too big, causing int32 overflow\r\n\r\nI was able to eliminate the problem by changing the reshape.py:\r\nmodify line 121from dtype np.int32 to dtype np.int64:\r\n `num_cells = np.multiply(num_rows, num_columns, dtype=np.int64)`\r\n\r\n\r\n#### Expected Output\r\n\r\nNot being limited by int32 dims when reshaping a data frame.\r\nThis feels like a restriction which should not be there.\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit: None\r\npython: 3.7.3.final.0\r\npython-bits: 64\r\nOS: Linux\r\nOS-release: 3.10.0-862.el7.x86_64\r\nmachine: x86_64\r\nprocessor: x86_64\r\nbyteorder: little\r\nLC_ALL: None\r\nLANG: en_US.UTF-8\r\nLOCALE: en_US.UTF-8\r\n\r\npandas: 0.24.2\r\npytest: None\r\npip: 19.1\r\nsetuptools: 41.0.1\r\nCython: 0.29.7\r\nnumpy: 1.16.3\r\nscipy: 1.2.1\r\npyarrow: None\r\nxarray: 0.12.1\r\nIPython: 7.5.0\r\nsphinx: None\r\npatsy: 0.5.1\r\ndateutil: 2.8.0\r\npytz: 2019.1\r\nblosc: None\r\nbottleneck: None\r\ntables: None\r\nnumexpr: None\r\nfeather: None\r\nmatplotlib: 3.0.3\r\nopenpyxl: 2.6.2\r\nxlrd: None\r\nxlwt: None\r\nxlsxwriter: None\r\nlxml.etree: None\r\nbs4: None\r\nhtml5lib: None\r\nsqlalchemy: 1.3.3\r\npymysql: None\r\npsycopg2: None\r\njinja2: 2.10.1\r\ns3fs: None\r\nfastparquet: 0.3.0\r\npandas_gbq: None\r\npandas_datareader: None\r\ngcsfs: None\r\n\r\n</details>\r\n'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26312',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26312/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26312/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26312/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/26312',
#   'id': 441465385,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Mjc2Nzg3NDUz',
#   'number': 26312,
#   'title': 'Added Hypothesis property-based test for timedelta addition',
#   'user': {'login': 'c74p',
#    'id': 41354105,
#    'node_id': 'MDQ6VXNlcjQxMzU0MTA1',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/41354105?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/c74p',
#    'html_url': 'https://github.com/c74p',
#    'followers_url': 'https://api.github.com/users/c74p/followers',
#    'following_url': 'https://api.github.com/users/c74p/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/c74p/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/c74p/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/c74p/subscriptions',
#    'organizations_url': 'https://api.github.com/users/c74p/orgs',
#    'repos_url': 'https://api.github.com/users/c74p/repos',
#    'events_url': 'https://api.github.com/users/c74p/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/c74p/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2019-05-07T22:03:06Z',
#   'updated_at': '2019-05-08T19:09:09Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/26312',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/26312',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/26312.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/26312.patch'},
#   'body': '- [ ] closes #xxxx\r\n- [1 ] tests added / passed\r\n- [ ] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [ ] whatsnew entry\r\n\r\n- This is the first pull request I\'ve done on any project in any language.  Any feedback, pointing to docs, requests to work on other issues instead, etc. happily accepted. Thanks for your work on Pandas!'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26310',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26310/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26310/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26310/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/26310',
#   'id': 441324728,
#   'node_id': 'MDU6SXNzdWU0NDEzMjQ3Mjg=',
#   'number': 26310,
#   'title': 'groupby.agg (first, last, min, etc...) returns incorrect results for uint64 columns',
#   'user': {'login': 'toliwaga',
#    'id': 58944,
#    'node_id': 'MDQ6VXNlcjU4OTQ0',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/58944?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/toliwaga',
#    'html_url': 'https://github.com/toliwaga',
#    'followers_url': 'https://api.github.com/users/toliwaga/followers',
#    'following_url': 'https://api.github.com/users/toliwaga/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/toliwaga/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/toliwaga/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/toliwaga/subscriptions',
#    'organizations_url': 'https://api.github.com/users/toliwaga/orgs',
#    'repos_url': 'https://api.github.com/users/toliwaga/repos',
#    'events_url': 'https://api.github.com/users/toliwaga/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/toliwaga/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False},
#    {'id': 31404521,
#     'node_id': 'MDU6TGFiZWwzMTQwNDUyMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dtypes',
#     'name': 'Dtypes',
#     'color': 'e102d8',
#     'default': False},
#    {'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2019-05-07T16:26:23Z',
#   'updated_at': '2019-05-07T23:38:53Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'body': "#### Code Sample, a copy-pastable example if possible\r\n\r\n```\r\nimport pandas as pd\r\nimport numpy as np\r\n\r\ndf = pd.DataFrame({'x': 6903052872240755750, 'y': [1,2]})\r\nprint(df.groupby('y').agg({'x': 'first'}))\r\ndf.x = df.x.astype(np.uint64)\r\nprint(df.groupby('y').agg({'x': 'first'}))\r\n```\r\n#### Problem description\r\n\r\ngroupby.agg (first, last, min, etc...) returns incorrect results for uint64 columns\r\n\r\n#### Expected Output\r\n\r\nexpect same results in both cases below:\r\n                     x\r\ny                     \r\n1  6903052872240755750\r\n2  6903052872240755750\r\n                     x\r\ny                     \r\n1  6903052872240755712\r\n2  6903052872240755712\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\n[paste the output of ``pd.show_versions()`` here below this line]\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit: None\r\npython: 3.6.8.final.0\r\npython-bits: 64\r\nOS: Darwin\r\nOS-release: 18.5.0\r\nmachine: x86_64\r\nprocessor: i386\r\nbyteorder: little\r\nLC_ALL: None\r\nLANG: en_US.UTF-8\r\nLOCALE: en_US.UTF-8\r\n\r\npandas: 0.24.2\r\npytest: None\r\npip: 19.1\r\nsetuptools: 41.0.1\r\nCython: None\r\nnumpy: 1.16.3\r\nscipy: 1.2.1\r\npyarrow: None\r\nxarray: None\r\nIPython: None\r\nsphinx: None\r\npatsy: None\r\ndateutil: 2.8.0\r\npytz: 2019.1\r\nblosc: None\r\nbottleneck: None\r\ntables: 3.5.1\r\nnumexpr: 2.6.9\r\nfeather: None\r\nmatplotlib: None\r\nopenpyxl: None\r\nxlrd: None\r\nxlwt: None\r\nxlsxwriter: None\r\nlxml.etree: None\r\nbs4: None\r\nhtml5lib: None\r\nsqlalchemy: None\r\npymysql: None\r\npsycopg2: None\r\njinja2: None\r\ns3fs: None\r\nfastparquet: None\r\npandas_gbq: None\r\npandas_datareader: None\r\ngcsfs: None\r\n\r\n</details>\r\n"},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26309',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26309/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26309/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26309/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/26309',
#   'id': 441292742,
#   'node_id': 'MDU6SXNzdWU0NDEyOTI3NDI=',
#   'number': 26309,
#   'title': 'Upsample spline interpolation with smoothing',
#   'user': {'login': 'tritemio',
#    'id': 4156237,
#    'node_id': 'MDQ6VXNlcjQxNTYyMzc=',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/4156237?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tritemio',
#    'html_url': 'https://github.com/tritemio',
#    'followers_url': 'https://api.github.com/users/tritemio/followers',
#    'following_url': 'https://api.github.com/users/tritemio/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/tritemio/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/tritemio/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/tritemio/subscriptions',
#    'organizations_url': 'https://api.github.com/users/tritemio/orgs',
#    'repos_url': 'https://api.github.com/users/tritemio/repos',
#    'events_url': 'https://api.github.com/users/tritemio/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/tritemio/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 74975453,
#     'node_id': 'MDU6TGFiZWw3NDk3NTQ1Mw==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Resample',
#     'name': 'Resample',
#     'color': '207de5',
#     'default': False},
#    {'id': 2413328,
#     'node_id': 'MDU6TGFiZWwyNDEzMzI4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Visualization',
#     'name': 'Visualization',
#     'color': '8AE234',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2019-05-07T15:20:41Z',
#   'updated_at': '2019-05-08T22:48:43Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'body': '#### Code Sample, a copy-pastable example if possible\r\n\r\n```python\r\nimport numpy as np\r\nimport pandas as pd\r\nfrom scipy import interpolate\r\nimport matplotlib.pyplot as plt\r\n\r\ndf = pd.read_csv(\'temp.csv\', parse_dates=[\'date_time\'], index_col=0)\r\n\r\ns = 0.3\r\nx = df.index.values\r\ny = df.temperature.values\r\nxnew = np.arange(x[0], x[-1], np.timedelta64(5, \'m\'))\r\n\r\ntck = interpolate.splrep(x, y, k=3, s=s)\r\nynew = interpolate.splev(xnew.view(int), tck)\r\n\r\ndf.temperature.plot(marker=\'o\', ls=\'\', label=\'data\')\r\nplt.plot(xnew, ynew, label=f\'scipy cubic spline (s={s})\')\r\n(df.temperature.resample(\'5min\')\r\n               .interpolate(method=\'spline\', order=3, s=s)\r\n               .plot(label=f\'pandas cubic spline (s={s})\'))\r\nplt.legend();\r\n```\r\n\r\nSee the same script as a notebook: \r\n\r\n- https://gist.github.com/tritemio/aea8c0e18e9bde6984ca199b7c012ad8\r\n\r\nSample data:\r\n\r\n- https://gist.github.com/tritemio/aea8c0e18e9bde6984ca199b7c012ad8#file-temp-csv\r\n\r\n#### Problem description\r\nSpline interpolation of order 3 with smoothing (`s>0`) gives an interpolation that does not pass through the data points. Scipy\'s version shows this behaviour. Pandas\'s version shows a smooth spline and then "jumps" in correspondence to the data points in order to "pass through the data". See figure below:\r\n\r\n<img width="380" alt="index" src="https://user-images.githubusercontent.com/4156237/57311250-8efbc180-70eb-11e9-8800-0fd467e198b8.png">\r\n\r\n\r\n#### Expected Output\r\n\r\nScipy and pandas interpolation should match.\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\n[paste the output of ``pd.show_versions()`` here below this line]\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit: None\r\npython: 3.7.2.final.0\r\npython-bits: 64\r\nOS: Darwin\r\nOS-release: 18.2.0\r\nmachine: x86_64\r\nprocessor: i386\r\nbyteorder: little\r\nLC_ALL: None\r\nLANG: en_US.UTF-8\r\nLOCALE: en_US.UTF-8\r\n\r\npandas: 0.24.2\r\npytest: 4.3.0\r\npip: 19.0.3\r\nsetuptools: 40.8.0\r\nCython: None\r\nnumpy: 1.16.2\r\nscipy: 1.2.1\r\npyarrow: None\r\nxarray: None\r\nIPython: 7.3.0\r\nsphinx: None\r\npatsy: 0.5.1\r\ndateutil: 2.8.0\r\npytz: 2018.9\r\nblosc: None\r\nbottleneck: 1.2.1\r\ntables: None\r\nnumexpr: 2.6.9\r\nfeather: None\r\nmatplotlib: 3.0.3\r\nopenpyxl: None\r\nxlrd: None\r\nxlwt: None\r\nxlsxwriter: None\r\nlxml.etree: 4.3.2\r\nbs4: 4.7.1\r\nhtml5lib: None\r\nsqlalchemy: None\r\npymysql: None\r\npsycopg2: None\r\njinja2: 2.10\r\ns3fs: None\r\nfastparquet: None\r\npandas_gbq: None\r\npandas_datareader: None\r\ngcsfs: None\r\n</details>\r\n'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26307',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26307/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26307/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26307/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/26307',
#   'id': 441250560,
#   'node_id': 'MDU6SXNzdWU0NDEyNTA1NjA=',
#   'number': 26307,
#   'title': 'Missing `GL06` and `GL07` errors for invalid docstrings',
#   'user': {'login': 'Scowley4',
#    'id': 32966226,
#    'node_id': 'MDQ6VXNlcjMyOTY2MjI2',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/32966226?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Scowley4',
#    'html_url': 'https://github.com/Scowley4',
#    'followers_url': 'https://api.github.com/users/Scowley4/followers',
#    'following_url': 'https://api.github.com/users/Scowley4/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Scowley4/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Scowley4/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Scowley4/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Scowley4/orgs',
#    'repos_url': 'https://api.github.com/users/Scowley4/repos',
#    'events_url': 'https://api.github.com/users/Scowley4/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Scowley4/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False},
#    {'id': 106935113,
#     'node_id': 'MDU6TGFiZWwxMDY5MzUxMTM=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Style',
#     'name': 'Style',
#     'color': 'eb6420',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2019-05-07T14:01:37Z',
#   'updated_at': '2019-05-08T22:47:30Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'body': "As discovered in the process of working on #26301, there are invalid docstrings that should throw either `GL06 - Found unknown section` or `GL07 - Sections are in the wrong order` errors.\r\n\r\nWithout too much investigation, it's not clear why `GL06` is not being thrown. Currently unsure if this is even a problem because, as @datapythonista mentioned in comments on #26301, we may not even run these checks on the private methods.\r\n\r\nThe missing `GL07` are because section headers were only considered section headers if the following line had an equal number of `-----`'s (underlines).\r\n\r\nThis code is found here (where `content[0]` is the section header):\r\nhttps://github.com/pandas-dev/pandas/blob/2bbc0c2c198374546408cb15fff447c1e306f99f/scripts/validate_docstrings.py#L383-L386\r\n\r\n- [x] Reorder sections that are failing #26301 and merge\r\n- [ ] ~Fix GL07 to correctly throw errors with invalid underlines~\r\n- [ ] ~Investigate GL06~\r\n- [ ] Add error for valid section title words with invalid number of underlines\r\n\r\nIf it's okay with others, I'd like to take a crack at this issue.\r\n\r\n"},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26306',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26306/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26306/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26306/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/26306',
#   'id': 441155633,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Mjc2NTM2OTg1',
#   'number': 26306,
#   'title': 'DOC: Improve links and fix issues on resample documentation page',
#   'user': {'login': 'Bharat123rox',
#    'id': 13381361,
#    'node_id': 'MDQ6VXNlcjEzMzgxMzYx',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/13381361?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Bharat123rox',
#    'html_url': 'https://github.com/Bharat123rox',
#    'followers_url': 'https://api.github.com/users/Bharat123rox/followers',
#    'following_url': 'https://api.github.com/users/Bharat123rox/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Bharat123rox/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Bharat123rox/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Bharat123rox/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Bharat123rox/orgs',
#    'repos_url': 'https://api.github.com/users/Bharat123rox/repos',
#    'events_url': 'https://api.github.com/users/Bharat123rox/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Bharat123rox/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False},
#    {'id': 53181044,
#     'node_id': 'MDU6TGFiZWw1MzE4MTA0NA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Frequency',
#     'name': 'Frequency',
#     'color': '0052cc',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/61',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/61',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/61/labels',
#    'id': 3759483,
#    'node_id': 'MDk6TWlsZXN0b25lMzc1OTQ4Mw==',
#    'number': 61,
#    'title': '0.25.0',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 75,
#    'closed_issues': 648,
#    'state': 'open',
#    'created_at': '2018-10-23T02:34:15Z',
#    'updated_at': '2019-05-08T14:58:25Z',
#    'due_on': '2019-06-01T07:00:00Z',
#    'closed_at': None},
#   'comments': 4,
#   'created_at': '2019-05-07T10:19:01Z',
#   'updated_at': '2019-05-08T03:45:20Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/26306',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/26306',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/26306.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/26306.patch'},
#   'body': '- [x] closes #26275 \r\n- [x] tests added / passed\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [ ] whatsnew entry (Not required IMO)\r\n'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26303',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26303/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26303/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26303/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/26303',
#   'id': 441063408,
#   'node_id': 'MDU6SXNzdWU0NDEwNjM0MDg=',
#   'number': 26303,
#   'title': 'MultiIndex DataFrame to_csv() terminates python process',
#   'user': {'login': 'miburk',
#    'id': 44474807,
#    'node_id': 'MDQ6VXNlcjQ0NDc0ODA3',
#    'avatar_url': 'https://avatars3.githubusercontent.com/u/44474807?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/miburk',
#    'html_url': 'https://github.com/miburk',
#    'followers_url': 'https://api.github.com/users/miburk/followers',
#    'following_url': 'https://api.github.com/users/miburk/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/miburk/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/miburk/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/miburk/subscriptions',
#    'organizations_url': 'https://api.github.com/users/miburk/orgs',
#    'repos_url': 'https://api.github.com/users/miburk/repos',
#    'events_url': 'https://api.github.com/users/miburk/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/miburk/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False},
#    {'id': 71268330,
#     'node_id': 'MDU6TGFiZWw3MTI2ODMzMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/MultiIndex',
#     'name': 'MultiIndex',
#     'color': '207de5',
#     'default': False},
#    {'id': 1121248195,
#     'node_id': 'MDU6TGFiZWwxMTIxMjQ4MTk1',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Segfault',
#     'name': 'Segfault',
#     'color': '36ede0',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/32',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32/labels',
#    'id': 933188,
#    'node_id': 'MDk6TWlsZXN0b25lOTMzMTg4',
#    'number': 32,
#    'title': 'Contributions Welcome',
#    'description': 'Changes that would be nice to have in the next release. These issues are not blocking. They will be pushed to the next release if no one has time to fix them.',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 1238,
#    'closed_issues': 377,
#    'state': 'open',
#    'created_at': '2015-01-13T10:53:19Z',
#    'updated_at': '2019-05-08T15:12:07Z',
#    'due_on': '2020-12-31T08:00:00Z',
#    'closed_at': None},
#   'comments': 1,
#   'created_at': '2019-05-07T06:36:48Z',
#   'updated_at': '2019-05-08T15:11:30Z',
#   'closed_at': None,
#   'author_association': 'NONE',
# ...
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26258',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26258/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26258/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26258/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/26258',
#   'id': 439228127,
#   'node_id': 'MDU6SXNzdWU0MzkyMjgxMjc=',
#   'number': 26258,
#   'title': 'Adding offset to DatetimeIndex is broken',
#   'user': {'login': 'mmamaev',
#    'id': 26414241,
#    'node_id': 'MDQ6VXNlcjI2NDE0MjQx',
#    'avatar_url': 'https://avatars0.githubusercontent.com/u/26414241?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mmamaev',
#    'html_url': 'https://github.com/mmamaev',
#    'followers_url': 'https://api.github.com/users/mmamaev/followers',
#    'following_url': 'https://api.github.com/users/mmamaev/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mmamaev/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mmamaev/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mmamaev/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mmamaev/orgs',
#    'repos_url': 'https://api.github.com/users/mmamaev/repos',
#    'events_url': 'https://api.github.com/users/mmamaev/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mmamaev/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False},
#    {'id': 53181044,
#     'node_id': 'MDU6TGFiZWw1MzE4MTA0NA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Frequency',
#     'name': 'Frequency',
#     'color': '0052cc',
#     'default': False},
#    {'id': 211840,
#     'node_id': 'MDU6TGFiZWwyMTE4NDA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timeseries',
#     'name': 'Timeseries',
#     'color': 'AFEEEE',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/61',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/61',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/61/labels',
#    'id': 3759483,
#    'node_id': 'MDk6TWlsZXN0b25lMzc1OTQ4Mw==',
#    'number': 61,
#    'title': '0.25.0',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 75,
#    'closed_issues': 648,
#    'state': 'open',
#    'created_at': '2018-10-23T02:34:15Z',
#    'updated_at': '2019-05-08T14:58:25Z',
#    'due_on': '2019-06-01T07:00:00Z',
#    'closed_at': None},
#   'comments': 2,
#   'created_at': '2019-05-01T16:31:58Z',
#   'updated_at': '2019-05-07T00:38:02Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'body': '#### Code Sample, a copy-pastable example if possible\r\n\r\n```python\r\nimport pandas as pd\r\noffset = pd.DateOffset(months=3, days=10)\r\ndates = pd.date_range(start=\'01 Jan 2014\', end=\'01 Jan 2017\', freq=\'AS\')\r\ndates + offset\r\n```\r\n\r\n#### Problem description\r\n\r\nValueError is raised:\r\n\r\n```python\r\n\r\nTraceback (most recent call last):\r\n  File "C:\\mma\\local\\Anaconda3\\envs\\pd24\\lib\\site-packages\\pandas\\core\\arrays\\datetimelike.py", line 884, in _validate_frequency\r\n    raise ValueError\r\nValueError\r\n\r\nDuring handling of the above exception, another exception occurred:\r\n\r\nTraceback (most recent call last):\r\n  File "<stdin>", line 1, in <module>\r\n  File "C:\\mma\\local\\Anaconda3\\envs\\pd24\\lib\\site-packages\\pandas\\core\\indexes\\datetimelike.py", line 489, in __add__\r\n    result = self._data.__add__(maybe_unwrap_index(other))\r\n  File "C:\\mma\\local\\Anaconda3\\envs\\pd24\\lib\\site-packages\\pandas\\core\\arrays\\datetimelike.py", line 1190, in __add__\r\n    result = self._add_offset(other)\r\n  File "C:\\mma\\local\\Anaconda3\\envs\\pd24\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 737, in _add_offset\r\n    result = offset.apply_index(values)\r\n  File "pandas/_libs/tslibs/offsets.pyx", line 116, in pandas._libs.tslibs.offsets.apply_index_wraps.wrapper\r\n  File "C:\\mma\\local\\Anaconda3\\envs\\pd24\\lib\\site-packages\\pandas\\tseries\\offsets.py", line 278, in apply_index\r\n    i = type(i)(shifted, freq=i.freq, dtype=i.dtype)\r\n  File "C:\\mma\\local\\Anaconda3\\envs\\pd24\\lib\\site-packages\\pandas\\core\\arrays\\datetimes.py", line 351, in __init__\r\n    type(self)._validate_frequency(self, freq)\r\n  File "C:\\mma\\local\\Anaconda3\\envs\\pd24\\lib\\site-packages\\pandas\\core\\arrays\\datetimelike.py", line 897, in _validate_frequency\r\n    .format(infer=inferred, passed=freq.freqstr))\r\nValueError: Inferred frequency AS-APR from passed values does not conform to passed frequency AS-JAN\r\n```\r\n\r\n#### Expected Output\r\n\r\nThis is what had been working through version 0.22.0 and was broken somewhere between 0.22 and 0.24:\r\n\r\n```python\r\n>>> dates + offset\r\nDatetimeIndex([\'2014-04-11\', \'2015-04-11\', \'2016-04-11\', \'2017-04-11\'], dtype=\'datetime64[ns]\', freq=None)\r\n```\r\n#### Workaround\r\n\r\n```python\r\n\r\n>>> pd.DatetimeIndex([date + offset for date in dates])\r\nDatetimeIndex([\'2014-04-11\', \'2015-04-11\', \'2016-04-11\', \'2017-04-11\'], dtype=\'datetime64[ns]\', freq=None)\r\n```\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit: None\r\npython: 3.6.8.final.0\r\npython-bits: 64\r\nOS: Windows\r\nOS-release: 7\r\nmachine: AMD64\r\nprocessor: Intel64 Family 6 Model 58 Stepping 9, GenuineIntel\r\nbyteorder: little\r\nLC_ALL: None\r\nLANG: None\r\nLOCALE: None.None\r\n\r\npandas: 0.24.2\r\npytest: 4.4.1\r\npip: 19.1\r\nsetuptools: 41.0.1\r\nCython: None\r\nnumpy: 1.16.3\r\nscipy: None\r\npyarrow: None\r\nxarray: None\r\nIPython: None\r\nsphinx: None\r\npatsy: None\r\ndateutil: 2.8.0\r\npytz: 2019.1\r\nblosc: None\r\nbottleneck: None\r\ntables: None\r\nnumexpr: None\r\nfeather: None\r\nmatplotlib: None\r\nopenpyxl: None\r\nxlrd: None\r\nxlwt: None\r\nxlsxwriter: None\r\nlxml.etree: None\r\nbs4: None\r\nhtml5lib: None\r\nsqlalchemy: None\r\npymysql: None\r\npsycopg2: None\r\njinja2: None\r\ns3fs: None\r\nfastparquet: None\r\npandas_gbq: None\r\npandas_datareader: None\r\ngcsfs: None\r\n\r\n</details>\r\n'},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26253',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26253/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26253/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26253/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/26253',
#   'id': 439056698,
#   'node_id': 'MDU6SXNzdWU0MzkwNTY2OTg=',
#   'number': 26253,
#   'title': "DateFormatter('%Y') for x-axis labels gives strange output for a specific date value",
#   'user': {'login': 'davehemming',
#    'id': 6355796,
#    'node_id': 'MDQ6VXNlcjYzNTU3OTY=',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/6355796?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/davehemming',
#    'html_url': 'https://github.com/davehemming',
#    'followers_url': 'https://api.github.com/users/davehemming/followers',
#    'following_url': 'https://api.github.com/users/davehemming/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/davehemming/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/davehemming/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/davehemming/subscriptions',
#    'organizations_url': 'https://api.github.com/users/davehemming/orgs',
#    'repos_url': 'https://api.github.com/users/davehemming/repos',
#    'events_url': 'https://api.github.com/users/davehemming/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/davehemming/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2413328,
#     'node_id': 'MDU6TGFiZWwyNDEzMzI4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Visualization',
#     'name': 'Visualization',
#     'color': '8AE234',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2019-05-01T03:21:28Z',
#   'updated_at': '2019-05-02T04:07:14Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'body': "```python\r\nimport numpy as np\r\nimport pandas as pd\r\nimport matplotlib.dates as md\r\nimport matplotlib.pyplot as plt\r\n\r\ndata = {\r\n    'date': [pd.Timestamp(2014, 9, 28), pd.Timestamp(2014, 10, 5), pd.Timestamp(2014, 10, 12)],\r\n    'val': [0.37,0.44,0.44]\r\n}\r\ndf = pd.DataFrame(data=data)\r\nax = df.plot(x='date', y='val')\r\nax.xaxis.set_major_formatter(md.DateFormatter('%Y'))\r\n```\r\n#### Problem description\r\nWhen I run the above code the plot generated should have x axis tick labels showing the year e.g. **'2014', '2014', '2014'**, etc.  Instead it has the labels **'0007', '0007', '0007'**.\r\n\r\nIf I increment the last date from '**2014-10-12**' to '**2014-10-13**' in the 'data' variable by one day (or really change it to anything else) like this:\r\n\r\n```python\r\ndata = {\r\n    'date': [pd.Timestamp(2014, 9, 28), pd.Timestamp(2014, 10, 5), pd.Timestamp(2014, 10, 13)],\r\n    'val': [0.37,0.44,0.44]\r\n}\r\n```\r\nThen rerun it, it works as expected.\r\n\r\n#### Expected Output\r\nx label on generated plot figure should be **'2014', '2014', '2014', ...**\r\n\r\n#### What else have you tried?\r\nI ran the same data using only numpy and matplotlib to rule that out as a source of the unexpected output and I was given the expected x-axis label formatting with **'2014', '2014', '2014'**, etc.  Here is my code for that;\r\n\r\n```python\r\ndata = np.array([\r\n    (np.datetime64('2014-09-28'), 0.37),\r\n    (np.datetime64('2014-10-05'), 0.44),\r\n    (np.datetime64('2014-10-12'), 0.44)], \r\n    dtype=[('date', 'datetime64[D]'), ('val', float)\r\n])\r\n\r\ndata = data.view(np.recarray)\r\nfig, ax = plt.subplots()\r\nax.plot(data.date, data.val)\r\nax.xaxis.set_major_formatter(md.DateFormatter('%Y'))\r\nplt.show()\r\n```\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit: None\r\npython: 3.6.8.final.0\r\npython-bits: 64\r\nOS: Darwin\r\nOS-release: 18.5.0\r\nmachine: x86_64\r\nprocessor: i386\r\nbyteorder: little\r\nLC_ALL: None\r\nLANG: en_AU.UTF-8\r\nLOCALE: en_AU.UTF-8\r\n\r\npandas: 0.24.2\r\npytest: None\r\npip: 19.0.3\r\nsetuptools: 41.0.0\r\nCython: None\r\nnumpy: 1.16.2\r\nscipy: 1.2.1\r\npyarrow: None\r\nxarray: 0.11.3\r\nIPython: 7.4.0\r\nsphinx: None\r\npatsy: None\r\ndateutil: 2.8.0\r\npytz: 2019.1\r\nblosc: None\r\nbottleneck: None\r\ntables: None\r\nnumexpr: None\r\nfeather: None\r\nmatplotlib: 3.0.3\r\nopenpyxl: None\r\nxlrd: None\r\nxlwt: None\r\nxlsxwriter: None\r\nlxml.etree: 4.3.3\r\nbs4: None\r\nhtml5lib: None\r\nsqlalchemy: None\r\npymysql: None\r\npsycopg2: None\r\njinja2: 2.10.1\r\ns3fs: None\r\nfastparquet: None\r\npandas_gbq: None\r\npandas_datareader: None\r\ngcsfs: None\r\n</details>\r\n"},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26249',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26249/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26249/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/26249/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/26249',
#   'id': 438893928,
#   'node_id': 'MDU6SXNzdWU0Mzg4OTM5Mjg=',
#   'number': 26249,
#   'title': 'Some cleanups of merge_asof tests and error code',
#   'user': {'login': 'chrish42',
#    'id': 632858,
#    'node_id': 'MDQ6VXNlcjYzMjg1OA==',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/632858?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chrish42',
#    'html_url': 'https://github.com/chrish42',
#    'followers_url': 'https://api.github.com/users/chrish42/followers',
#    'following_url': 'https://api.github.com/users/chrish42/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/chrish42/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/chrish42/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/chrish42/subscriptions',
#    'organizations_url': 'https://api.github.com/users/chrish42/orgs',
#    'repos_url': 'https://api.github.com/users/chrish42/repos',
#    'events_url': 'https://api.github.com/users/chrish42/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/chrish42/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False},
#    {'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 5,
#   'created_at': '2019-04-30T17:35:24Z',
#   'updated_at': '2019-05-03T15:38:49Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'body': 'This is a follow-up to #26242, for the following points:\r\n- [ ] Add test in `test_merge_asof.py` that checks that `merge_asof()` raises an exception if called on unordered categories for a merge key.\r\n- [ ] Remove docstrings in tests in `test_merge_asof.py`\r\n- [ ] Add test to check that `merge_asof` works when one of the merge keys is an ordered categorical\r\n- [ ] Raise MergeError sooner (rather than the ValueError that happens later) when asked to do a merge and one of the keys is an unordered categorical.\r\n- [ ] use `repr(x.dtype)` instead of `x.dtype` as input to `.format()` in exception messages everywhere in merge.py'}]

# %%
data[0]['title']
# Out:
# 'Bug: Groupby with as_index=True causes incorrect summarization'

# %%
issues=pd.DataFrame(data,columns=['title','number','user','id'])

# %%
issues
# Out:
#                                                 title  number  \
# 0   Bug: Groupby with as_index=True causes incorre...   26321
# 1   __or__ (and others?) should return NotImplemen...   26320
# 2                   CLN: remove compat.lrange, part 3   26319
# 3         [ENH] Use default EA repr for IntervalArray   26316
# 4   Remove other pandas.core.index files from MyPy...   26315
# 5   Pivot / unstack on large data frame does not w...   26314
# 6   Added Hypothesis property-based test for timed...   26312
# 7   groupby.agg (first, last, min, etc...) returns...   26310
# 8        Upsample spline interpolation with smoothing   26309
# 9   Missing `GL06` and `GL07` errors for invalid d...   26307
# 10  DOC: Improve links and fix issues on resample ...   26306
# 11  MultiIndex DataFrame to_csv() terminates pytho...   26303
# 12        Add Annotations to assert_*_equal functions   26302
# 13    Fix type annotations in pandas.core.config_init   26299
# 14  BUG-20629 allow .at accessor with CategoricalI...   26298
# 15  Changes to major/minor locator on a DateTime i...   26293
# 16  [BUG] Adding offset with nonzero month to Date...   26292
# 17                   Pandas UTF-8 handling is rubbish   26290
# 18           Sparse DF with time column cannot concat   26288
# 19  json_normalize should raise when record_path d...   26284
# 20  BUG: Series.combine_first raises ValueError on...   26283
# 21      BUG: Fix #26210: MultiIndex Sorting with NaNs   26282
# 22  Remove pandas.core.index.datetimelike from MyP...   26280
# 23  Feature request: easier digit format in to_lat...   26278
# 24    Links on resample documentation page are broken   26275
# 25      WIP: Maintain Int64 Precision on Construction   26272
# 26  Int64Dtype in read_csv leads to unexpected values   26259
# 27           Adding offset to DatetimeIndex is broken   26258
# 28  DateFormatter('%Y') for x-axis labels gives st...   26253
# 29   Some cleanups of merge_asof tests and error code   26249
#
#                                                  user         id
# 0   {'login': 'cdknox', 'id': 26149009, 'node_id':...  442032769
# 1   {'login': 'adamklein', 'id': 869232, 'node_id'...  441899956
# 2   {'login': 'topper-123', 'id': 26364415, 'node_...  441798290
# 3   {'login': 'makbigc', 'id': 14367887, 'node_id'...  441697121
# 4   {'login': 'makbigc', 'id': 14367887, 'node_id'...  441680417
# 5   {'login': 'MarkiesFredje', 'id': 28642372, 'no...  441643259
# 6   {'login': 'c74p', 'id': 41354105, 'node_id': '...  441465385
# 7   {'login': 'toliwaga', 'id': 58944, 'node_id': ...  441324728
# 8   {'login': 'tritemio', 'id': 4156237, 'node_id'...  441292742
# 9   {'login': 'Scowley4', 'id': 32966226, 'node_id...  441250560
# 10  {'login': 'Bharat123rox', 'id': 13381361, 'nod...  441155633
# 11  {'login': 'miburk', 'id': 44474807, 'node_id':...  441063408
# 12  {'login': 'WillAyd', 'id': 609873, 'node_id': ...  440977736
# 13  {'login': 'gwrome', 'id': 1430066, 'node_id': ...  440943241
# 14  {'login': 'JustinZhengBC', 'id': 29615021, 'no...  440878540
# 15  {'login': 'metaswirl', 'id': 1880943, 'node_id...  440728607
# 16  {'login': 'makbigc', 'id': 14367887, 'node_id'...  440668379
# 17  {'login': 'james-martin-engineer', 'id': 48542...  440554614
# 18  {'login': 'ruiann', 'id': 5110107, 'node_id': ...  440531515
# 19  {'login': 'Marky0', 'id': 4273841, 'node_id': ...  440458869
# 20  {'login': 'DomKennedy', 'id': 10784275, 'node_...  440432907
# 21  {'login': 'eoincondron', 'id': 9717992, 'node_...  440344877
# 22  {'login': 'makbigc', 'id': 14367887, 'node_id'...  440274429
# 23  {'login': 'kolibril13', 'id': 44469195, 'node_...  440151367
# 24  {'login': 'larsrinn', 'id': 22575361, 'node_id...  439937202
# 25  {'login': 'WillAyd', 'id': 609873, 'node_id': ...  439880651
# 26  {'login': 'alohr', 'id': 748655, 'node_id': 'M...  439235605
# 27  {'login': 'mmamaev', 'id': 26414241, 'node_id'...  439228127
# 28  {'login': 'davehemming', 'id': 6355796, 'node_...  439056698
# 29  {'login': 'chrish42', 'id': 632858, 'node_id':...  438893928

# %% [markdown]
# ##### Interacting with Databases

# %% [markdown]
# Loading data from SQL into a DataFrame is fairly straightforward, and pandas has
# some functions to simplify the process. As an example, I’ll create a SQLite database
# using Python’s built-in sqlite3 driver:

# %%
import sqlite3

# %%
query="""
CREATE TABLE test(
a VARCHAR(20),b VARCHAR(20),c REAL, d INTEGER
);
"""

# %%
con=sqlite3.connect('mysqldata.sqlite')

# %%
con.execute(query)

# %%
con.commit()

# %%
data=[('Atlanta', 'Georgia', 1.25, 6),('Tallahassee', 'Florida', 2.6, 3),('Sacramento', 'California', 1.7, 5)]

# %%
stmt="insert into test Values(?,?,?,?)"
con.executemany(stmt,data)

# %%
con.commit()

# %% [raw]
# Most Python SQL drivers (PyODBC, psycopg2, MySQLdb, pymssql, etc.) return a list
# of tuples when selecting data from a table:

# %%
cursor=con.execute('select * from test')
rows=cursor.fetchall()

# %%
rows
# Out:
# [('Atlanta', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('Sacramento', 'California', 1.7, 5)]

# %% [markdown]
# You can pass the list of tuples to the DataFrame constructor, but you also need the
# column names, contained in the cursor’s description attribute:

# %%
cursor.description
# Out:
# (('a', None, None, None, None, None, None),
#  ('b', None, None, None, None, None, None),
#  ('c', None, None, None, None, None, None),
#  ('d', None, None, None, None, None, None))

# %%
dfsql=pd.DataFrame(rows,columns=[x[0] for x in cursor.description])

# %%
dfsql
# Out:
#              a           b     c  d
# 0      Atlanta     Georgia  1.25  6
# 1  Tallahassee     Florida  2.60  3
# 2   Sacramento  California  1.70  5

# %% [markdown]
# This is quite a bit of munging that you’d rather not repeat each time you query the
# database. The SQLAlchemy project is a popular Python SQL toolkit that abstracts
# away many of the common differences between SQL databases. pandas has a
# read_sql function that enables you to read data easily from a general SQLAlchemy
# connection. Here, we’ll connect to the same SQLite database with SQLAlchemy and
# read data from the table created before:

# %%
import sqlalchemy as sqla

# %%
db=sqla.create_engine("sqlite:///mysqldata.sqlite")
pd.read_sql("select * from test",db)
# Out:
#              a           b     c  d
# 0      Atlanta     Georgia  1.25  6
# 1  Tallahassee     Florida  2.60  3
# 2   Sacramento  California  1.70  5
