# %%
from datetime import datetime
import pandas as pd
import numpy as np

# %%
now=datetime.now()

# %%
now
# Out:
# datetime.datetime(2019, 5, 12, 16, 47, 38, 788400)

# %%
now.date
# Out:
# <function datetime.date>

# %%
now.year
# Out:
# 2019

# %%
now.year,now.month,now.day
# Out:
# (2019, 5, 12)

# %%
now.time
# Out:
# <function datetime.time>

# %%
df=pd.read_csv('AAPL.csv',parse_dates=['Date'],index_col='Date')

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-14  189.009995  189.529999  187.860001  188.149994  185.328918
# 2018-05-15  186.779999  187.070007  185.100006  186.440002  183.644577
# 2018-05-16  186.070007  188.460007  186.000000  188.179993  185.358475
# 2018-05-17  188.000000  188.910004  186.360001  186.990005  184.186310
# 2018-05-18  187.190002  187.809998  186.130005  186.309998  183.516510
#
#               Volume
# Date
# 2018-05-14  20778800
# 2018-05-15  23695200
# 2018-05-16  19183100
# 2018-05-17  17294000
# 2018-05-18  18297700

# %%
type(df.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df.index
# Out:
# DatetimeIndex(['2018-05-14', '2018-05-15', '2018-05-16', '2018-05-17',
#                '2018-05-18', '2018-05-21', '2018-05-22', '2018-05-23',
#                '2018-05-24', '2018-05-25',
#                ...
#                '2019-04-29', '2019-04-30', '2019-05-01', '2019-05-02',
#                '2019-05-03', '2019-05-06', '2019-05-07', '2019-05-08',
#                '2019-05-09', '2019-05-10'],
#               dtype='datetime64[ns]', name='Date', length=250, freq=None)

# %%
df["2018-05"]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-05-14  189.009995  189.529999  187.860001  188.149994  185.328918
# 2018-05-15  186.779999  187.070007  185.100006  186.440002  183.644577
# 2018-05-16  186.070007  188.460007  186.000000  188.179993  185.358475
# 2018-05-17  188.000000  188.910004  186.360001  186.990005  184.186310
# 2018-05-18  187.190002  187.809998  186.130005  186.309998  183.516510
# 2018-05-21  188.000000  189.270004  186.910004  187.630005  184.816711
# 2018-05-22  188.380005  188.880005  186.779999  187.160004  184.353760
# 2018-05-23  186.350006  188.500000  185.759995  188.360001  185.535767
# 2018-05-24  188.770004  188.839996  186.210007  188.149994  185.328918
# 2018-05-25  188.229996  189.649994  187.649994  188.580002  185.752487
# 2018-05-29  187.600006  188.750000  186.869995  187.899994  185.082672
# 2018-05-30  187.720001  188.000000  186.779999  187.500000  184.688675
# ...

# %%
df.Close.resample('M').mean()
# Out:
# Date
# 2018-05-31    187.555384
# 2018-06-30    188.621429
# 2018-07-31    190.311429
# 2018-08-31    213.346089
# 2018-09-30    222.073685
# 2018-10-31    220.845652
# 2018-11-30    191.235714
# 2018-12-31    164.266317
# 2019-01-31    154.166190
# 2019-02-28    171.727893
# 2019-03-31    183.293810
# 2019-04-30    200.516191
# 2019-05-31    205.444998
# Freq: M, Name: Close, dtype: float64

# %%
# %matplotlib inline

# %%
df.Close.resample('M').mean().plot(kind='bar')

# %%
d=pd.date_range('2018/05/04','2018/06/08',freq='B')

# %%
d
# Out:
# DatetimeIndex(['2018-05-04', '2018-05-07', '2018-05-08', '2018-05-09',
#                '2018-05-10', '2018-05-11', '2018-05-14', '2018-05-15',
#                '2018-05-16', '2018-05-17', '2018-05-18', '2018-05-21',
#                '2018-05-22', '2018-05-23', '2018-05-24', '2018-05-25',
#                '2018-05-28', '2018-05-29', '2018-05-30', '2018-05-31',
#                '2018-06-01', '2018-06-04', '2018-06-05', '2018-06-06',
#                '2018-06-07', '2018-06-08'],
#               dtype='datetime64[ns]', freq='B')

# %%
d=pd.date_range('2018/05/04',periods=9,freq='B')

# %%
d
# Out:
# DatetimeIndex(['2018-05-04', '2018-05-07', '2018-05-08', '2018-05-09',
#                '2018-05-10', '2018-05-11', '2018-05-14', '2018-05-15',
#                '2018-05-16'],
#               dtype='datetime64[ns]', freq='B')

# %%
df=pd.read_csv('AAPL_without_date.csv')

# %%
date=pd.date_range('2018/05/04',periods=len(df),freq='B')

# %%
df.set_index(date,inplace=True)

# %%
df.asfreq('D').mean().plot()

# %%
df.asfreq('D',method='pad').Low.plot(kind='Pie')

# %%
date1=pd.date_range(start='2018/05/04',periods=72,freq='H')

# %%
date1
# Out:
# DatetimeIndex(['2018-05-04 00:00:00', '2018-05-04 01:00:00',
#                '2018-05-04 02:00:00', '2018-05-04 03:00:00',
#                '2018-05-04 04:00:00', '2018-05-04 05:00:00',
#                '2018-05-04 06:00:00', '2018-05-04 07:00:00',
#                '2018-05-04 08:00:00', '2018-05-04 09:00:00',
#                '2018-05-04 10:00:00', '2018-05-04 11:00:00',
#                '2018-05-04 12:00:00', '2018-05-04 13:00:00',
#                '2018-05-04 14:00:00', '2018-05-04 15:00:00',
#                '2018-05-04 16:00:00', '2018-05-04 17:00:00',
#                '2018-05-04 18:00:00', '2018-05-04 19:00:00',
#                '2018-05-04 20:00:00', '2018-05-04 21:00:00',
#                '2018-05-04 22:00:00', '2018-05-04 23:00:00',
#                '2018-05-05 00:00:00', '2018-05-05 01:00:00',
#                '2018-05-05 02:00:00', '2018-05-05 03:00:00',
#                '2018-05-05 04:00:00', '2018-05-05 05:00:00',
# ...

# %%
ser1=pd.Series(np.random.randn(len(date1)),index=date1)

# %%
ser1
# Out:
# 2018-05-04 00:00:00    1.001255
# 2018-05-04 01:00:00    0.496873
# 2018-05-04 02:00:00    0.113105
# 2018-05-04 03:00:00    0.200657
# 2018-05-04 04:00:00    0.495846
# 2018-05-04 05:00:00    1.916580
# 2018-05-04 06:00:00   -1.183726
# 2018-05-04 07:00:00   -0.085122
# 2018-05-04 08:00:00   -1.343877
# 2018-05-04 09:00:00    0.511477
# 2018-05-04 10:00:00    0.948960
# 2018-05-04 11:00:00   -0.895400
# 2018-05-04 12:00:00    0.348492
# 2018-05-04 13:00:00   -1.130496
# 2018-05-04 14:00:00   -1.027596
# 2018-05-04 15:00:00    0.555682
# 2018-05-04 16:00:00   -0.195574
# 2018-05-04 17:00:00   -1.246838
# 2018-05-04 18:00:00   -0.485582
# 2018-05-04 19:00:00   -0.160786
# 2018-05-04 20:00:00   -2.309550
# 2018-05-04 21:00:00   -0.810550
# 2018-05-04 22:00:00    1.062205
# 2018-05-04 23:00:00   -0.544347
# 2018-05-05 00:00:00    1.279403
# 2018-05-05 01:00:00   -0.819352
# 2018-05-05 02:00:00    0.014614
# 2018-05-05 03:00:00   -0.438562
# 2018-05-05 04:00:00   -1.676625
# ...

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay

# %%
us=CustomBusinessDay(calendar=USFederalHolidayCalendar())
us

# %%
d=pd.date_range('2017/06/03','2017/07/06',freq=us)

# %%
d
# Out:
# DatetimeIndex(['2017-06-05', '2017-06-06', '2017-06-07', '2017-06-08',
#                '2017-06-09', '2017-06-12', '2017-06-13', '2017-06-14',
#                '2017-06-15', '2017-06-16', '2017-06-19', '2017-06-20',
#                '2017-06-21', '2017-06-22', '2017-06-23', '2017-06-26',
#                '2017-06-27', '2017-06-28', '2017-06-29', '2017-06-30',
#                '2017-07-03', '2017-07-05', '2017-07-06'],
#               dtype='datetime64[ns]', freq='C')

# %%
d=pd.date_range('2017/06/03','2017/07/06',freq='B')

# %%
d
# Out:
# DatetimeIndex(['2017-06-05', '2017-06-06', '2017-06-07', '2017-06-08',
#                '2017-06-09', '2017-06-12', '2017-06-13', '2017-06-14',
#                '2017-06-15', '2017-06-16', '2017-06-19', '2017-06-20',
#                '2017-06-21', '2017-06-22', '2017-06-23', '2017-06-26',
#                '2017-06-27', '2017-06-28', '2017-06-29', '2017-06-30',
#                '2017-07-03', '2017-07-04', '2017-07-05', '2017-07-06'],
#               dtype='datetime64[ns]', freq='B')

# %%
pd.to_datetime(['4 jan 2018'])
# Out:
# DatetimeIndex(['2018-01-04'], dtype='datetime64[ns]', freq=None)

# %%
from tabula import read_pdf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-159-5c1882f30047> in <module>
# ----> 1 from tabula import read_pdf
#
# ModuleNotFoundError: No module named 'tabula'

# %%
# %pip install tabula-py
# Out:
# ...
#     100% |████████████████████████████████| 20.4MB 2.0MB/s eta 0:00:01   32% |██████████▌                     | 6.7MB 6.6MB/s eta 0:00:03
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tabula import read_pdf

# %%
import pandas as pd

# %%
df=read_pdf('Maths-class-11.pdf')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/tabula/wrapper.py in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, **kwargs)
#     107     try:
# --> 108         output = subprocess.check_output(args)
#     109
#
# ~/anaconda3/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# ~/anaconda3/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     471
# --> 472     with Popen(*popenargs, **kwargs) as process:
#     473         try:
#
# ...
